# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import numpy as np
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('train.csv')
df.head()
# Out:
#    PRT_ID        AREA  INT_SQFT   DATE_SALE  DIST_MAINROAD  N_BEDROOM  \
# 0  P03210  Karapakkam      1004  04-05-2011            131        1.0
# 1  P09411  Anna Nagar      1986  19-12-2006             26        2.0
# 2  P01812       Adyar       909  04-02-2012             70        1.0
# 3  P05346   Velachery      1855  13-03-2010             14        3.0
# 4  P06210  Karapakkam      1226  05-10-2009             84        1.0
#
#    N_BATHROOM  N_ROOM SALE_COND PARK_FACIL  ... UTILITY_AVAIL  STREET MZZONE  \
# 0         1.0       3  AbNormal        Yes  ...        AllPub   Paved      A
# 1         1.0       5  AbNormal         No  ...        AllPub  Gravel     RH
# 2         1.0       3  AbNormal        Yes  ...           ELO  Gravel     RL
# 3         2.0       5    Family         No  ...       NoSewr    Paved      I
# 4         1.0       3  AbNormal        Yes  ...        AllPub  Gravel      C
#
#   QS_ROOMS QS_BATHROOM  QS_BEDROOM  QS_OVERALL  REG_FEE  COMMIS  SALES_PRICE
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7109 entries, 0 to 7108
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   PRT_ID         7109 non-null   object
#  1   AREA           7109 non-null   object
#  2   INT_SQFT       7109 non-null   int64
#  3   DATE_SALE      7109 non-null   object
#  4   DIST_MAINROAD  7109 non-null   int64
#  5   N_BEDROOM      7108 non-null   float64
#  6   N_BATHROOM     7104 non-null   float64
#  7   N_ROOM         7109 non-null   int64
#  8   SALE_COND      7109 non-null   object
#  9   PARK_FACIL     7109 non-null   object
#  10  DATE_BUILD     7109 non-null   object
#  11  BUILDTYPE      7109 non-null   object
#  12  UTILITY_AVAIL  7109 non-null   object
#  13  STREET         7109 non-null   object
#  14  MZZONE         7109 non-null   object
#  15  QS_ROOMS       7109 non-null   float64
#  16  QS_BATHROOM    7109 non-null   float64
# ...

# %%
df.describe()
# Out:
#           INT_SQFT  DIST_MAINROAD    N_BEDROOM   N_BATHROOM       N_ROOM  \
# count  7109.000000    7109.000000  7108.000000  7104.000000  7109.000000
# mean   1382.073006      99.603179     1.637029     1.213260     3.688704
# std     457.410902      57.403110     0.802902     0.409639     1.019099
# min     500.000000       0.000000     1.000000     1.000000     2.000000
# 25%     993.000000      50.000000     1.000000     1.000000     3.000000
# 50%    1373.000000      99.000000     1.000000     1.000000     4.000000
# 75%    1744.000000     148.000000     2.000000     1.000000     4.000000
# max    2500.000000     200.000000     4.000000     2.000000     6.000000
#
#           QS_ROOMS  QS_BATHROOM   QS_BEDROOM   QS_OVERALL        REG_FEE  \
# count  7109.000000  7109.000000  7109.000000  7061.000000    7109.000000
# mean      3.517471     3.507244     3.485300     3.503254  376938.330708
# std       0.891972     0.897834     0.887266     0.527223  143070.662010
# ...

# %%
df.isna().sum()
# Out:
# PRT_ID            0
# AREA              0
# INT_SQFT          0
# DATE_SALE         0
# DIST_MAINROAD     0
# N_BEDROOM         1
# N_BATHROOM        5
# N_ROOM            0
# SALE_COND         0
# PARK_FACIL        0
# DATE_BUILD        0
# BUILDTYPE         0
# UTILITY_AVAIL     0
# STREET            0
# MZZONE            0
# QS_ROOMS          0
# QS_BATHROOM       0
# QS_BEDROOM        0
# QS_OVERALL       48
# REG_FEE           0
# COMMIS            0
# SALES_PRICE       0
# dtype: int64

# %%
df['N_BATHROOM']=df['N_BATHROOM'].fillna(1.0)

# %%
df.isna().sum()
# Out:
# PRT_ID            0
# AREA              0
# INT_SQFT          0
# DATE_SALE         0
# DIST_MAINROAD     0
# N_BEDROOM         1
# N_BATHROOM        0
# N_ROOM            0
# SALE_COND         0
# PARK_FACIL        0
# DATE_BUILD        0
# BUILDTYPE         0
# UTILITY_AVAIL     0
# STREET            0
# MZZONE            0
# QS_ROOMS          0
# QS_BATHROOM       0
# QS_BEDROOM        0
# QS_OVERALL       48
# REG_FEE           0
# COMMIS            0
# SALES_PRICE       0
# dtype: int64

# %%
df.corr()['SALES_PRICE']
# Out:
# INT_SQFT         0.612125
# DIST_MAINROAD    0.018783
# N_BEDROOM        0.330999
# N_BATHROOM       0.108834
# N_ROOM           0.602760
# QS_ROOMS         0.021967
# QS_BATHROOM     -0.011377
# QS_BEDROOM       0.018804
# QS_OVERALL       0.020556
# REG_FEE          0.878148
# COMMIS           0.626275
# SALES_PRICE      1.000000
# Name: SALES_PRICE, dtype: float64

# %%
sns.scatterplot(df['INT_SQFT'],df['SALES_PRICE'],hue=df.BUILDTYPE)

# %%
sns.barplot(df.N_ROOM,df.SALES_PRICE)

# %%
def continous(column):
    sns.scatterplot(df[column],df.SALES_PRICE,hue=df.BUILDTYPE)
def categorical(column):
    sns.barplot(df[column],df.SALES_PRICE)

# %%
continous('REG_FEE')

# %%
continous('COMMIS')

# %%
df['AGE']=df.DATE_BUILD.apply(lambda x : 2020-int(x[len(x)-4:len(x)]))
df['AGE'].head()
# Out:
# 0    53
# 1    25
# 2    28
# 3    32
# 4    41
# Name: AGE, dtype: int64

# %%
continous('AGE')

# %%
sns.boxplot(df.N_ROOM,df.SALES_PRICE)

# %%
sns.boxplot(df.N_BEDROOM,df.SALES_PRICE)

# %%
df.AREA.value_counts()
# Out:
# Chrompet      1681
# Karapakkam    1363
# KK Nagar       996
# Velachery      979
# Anna Nagar     783
# Adyar          773
# T Nagar        496
# Chrompt          9
# Chormpet         6
# Chrmpet          6
# TNagar           5
# Ana Nagar        3
# Karapakam        3
# Velchery         2
# Ann Nagar        2
# Adyr             1
# KKNagar          1
# Name: AREA, dtype: int64

# %%
df.AREA.replace({
    'Chrompt':'Chrompet',
    'Chormpet':'Chrompet',
    'Chrmpet':'Chrompet',
    'TNagar':'T Nagar',
    'Ana Nagar':'Anna Nagar',
    'Karapakam':'Karapakkam',
    'Ann Nagar':'Anna Nagar',
    'Velchery':'Velachery',
    'Adyr':'Adyar',
    'KKNagar':'KK Nagar'
},inplace=True)

# %%
df.AREA.value_counts()
# Out:
# Chrompet      1702
# Karapakkam    1366
# KK Nagar       997
# Velachery      981
# Anna Nagar     788
# Adyar          774
# T Nagar        501
# Name: AREA, dtype: int64

# %%
df.BUILDTYPE.value_counts()
# Out:
# House         2444
# Commercial    2325
# Others        2310
# Other           26
# Comercial        4
# Name: BUILDTYPE, dtype: int64

# %%
df.BUILDTYPE.replace({
    'Comercial':'Commercial',
    'Other':'Others'
},inplace=True)

# %%
df.BUILDTYPE.value_counts()
# Out:
# House         2444
# Others        2336
# Commercial    2329
# Name: BUILDTYPE, dtype: int64

# %%
df.PARK_FACIL.value_counts()
# Out:
# Yes    3587
# No     3520
# Noo       2
# Name: PARK_FACIL, dtype: int64

# %%
df.PARK_FACIL.replace({
    'Noo':'No'
},inplace=True)

# %%
df.PARK_FACIL.value_counts()
# Out:
# Yes    3587
# No     3522
# Name: PARK_FACIL, dtype: int64

# %%
df.corr().SALES_PRICE.sort_values(ascending=False)
# Out:
# SALES_PRICE      1.000000
# REG_FEE          0.878148
# COMMIS           0.626275
# INT_SQFT         0.612125
# N_ROOM           0.602760
# N_BEDROOM        0.330999
# N_BATHROOM       0.108834
# QS_ROOMS         0.021967
# QS_OVERALL       0.020556
# QS_BEDROOM       0.018804
# DIST_MAINROAD    0.018783
# QS_BATHROOM     -0.011377
# AGE             -0.116043
# Name: SALES_PRICE, dtype: float64

# %%
df1=df.drop(['QS_ROOMS','QS_OVERALL','QS_BEDROOM','DIST_MAINROAD','QS_BATHROOM'],axis='columns')
df1.head()
# Out:
#    PRT_ID        AREA  INT_SQFT   DATE_SALE  N_BEDROOM  N_BATHROOM  N_ROOM  \
# 0  P03210  Karapakkam      1004  04-05-2011        1.0         1.0       3
# 1  P09411  Anna Nagar      1986  19-12-2006        2.0         1.0       5
# 2  P01812       Adyar       909  04-02-2012        1.0         1.0       3
# 3  P05346   Velachery      1855  13-03-2010        3.0         2.0       5
# 4  P06210  Karapakkam      1226  05-10-2009        1.0         1.0       3
#
#   SALE_COND PARK_FACIL  DATE_BUILD   BUILDTYPE UTILITY_AVAIL  STREET MZZONE  \
# 0  AbNormal        Yes  15-05-1967  Commercial        AllPub   Paved      A
# 1  AbNormal         No  22-12-1995  Commercial        AllPub  Gravel     RH
# 2  AbNormal        Yes  09-02-1992  Commercial           ELO  Gravel     RL
# 3    Family         No  18-03-1988      Others       NoSewr    Paved      I
# 4  AbNormal        Yes  13-10-1979      Others        AllPub  Gravel      C
#
#    REG_FEE  COMMIS  SALES_PRICE  AGE
# ...

# %%
df1['DATE_SALE']=df1.DATE_SALE.apply(lambda x : 2020-int(x[len(x)-4:len(x)]))
df1['AGE']=df1.AGE-df1.DATE_SALE

# %%
df1.head()
# Out:
#    PRT_ID        AREA  INT_SQFT  DATE_SALE  N_BEDROOM  N_BATHROOM  N_ROOM  \
# 0  P03210  Karapakkam      1004          9        1.0         1.0       3
# 1  P09411  Anna Nagar      1986         14        2.0         1.0       5
# 2  P01812       Adyar       909          8        1.0         1.0       3
# 3  P05346   Velachery      1855         10        3.0         2.0       5
# 4  P06210  Karapakkam      1226         11        1.0         1.0       3
#
#   SALE_COND PARK_FACIL  DATE_BUILD   BUILDTYPE UTILITY_AVAIL  STREET MZZONE  \
# 0  AbNormal        Yes  15-05-1967  Commercial        AllPub   Paved      A
# 1  AbNormal         No  22-12-1995  Commercial        AllPub  Gravel     RH
# 2  AbNormal        Yes  09-02-1992  Commercial           ELO  Gravel     RL
# 3    Family         No  18-03-1988      Others       NoSewr    Paved      I
# 4  AbNormal        Yes  13-10-1979      Others        AllPub  Gravel      C
#
#    REG_FEE  COMMIS  SALES_PRICE  AGE
# ...

# %%
df2=df1.drop(['PRT_ID','DATE_SALE','SALE_COND','DATE_BUILD','UTILITY_AVAIL','STREET','MZZONE'],axis='columns')
df2
# Out:
#             AREA  INT_SQFT  N_BEDROOM  N_BATHROOM  N_ROOM PARK_FACIL  \
# 0     Karapakkam      1004        1.0         1.0       3        Yes
# 1     Anna Nagar      1986        2.0         1.0       5         No
# 2          Adyar       909        1.0         1.0       3        Yes
# 3      Velachery      1855        3.0         2.0       5         No
# 4     Karapakkam      1226        1.0         1.0       3        Yes
# ...          ...       ...        ...         ...     ...        ...
# 7104  Karapakkam       598        1.0         1.0       2         No
# 7105   Velachery      1897        3.0         2.0       5        Yes
# 7106   Velachery      1614        2.0         1.0       4         No
# 7107  Karapakkam       787        1.0         1.0       2        Yes
# 7108   Velachery      1896        3.0         2.0       5        Yes
#
#        BUILDTYPE  REG_FEE  COMMIS  SALES_PRICE  AGE
# 0     Commercial   380000  144400      7600000   44
# ...

# %%
df2.isna().sum()
# Out:
# AREA           0
# INT_SQFT       0
# N_BEDROOM      1
# N_BATHROOM     0
# N_ROOM         0
# PARK_FACIL     0
# BUILDTYPE      0
# REG_FEE        0
# COMMIS         0
# SALES_PRICE    0
# AGE            0
# dtype: int64

# %%
df2=df2.dropna()

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
df2['AREA']=le.fit_transform(df2['AREA'])       #[Adyar,Anna nagar,Chrompet,KK Nagar,Karapakkam,T Nagar,Velachery]

# %%
df2['BUILDTYPE']=le.fit_transform(df2['BUILDTYPE'])  #[Commerical,House,Others]

# %%
df2['PARK_FACIL']=le.fit_transform(df2['PARK_FACIL'])

# %%
df2.head()
# Out:
#    AREA  INT_SQFT  N_BEDROOM  N_BATHROOM  N_ROOM  PARK_FACIL  BUILDTYPE  \
# 0     4      1004        1.0         1.0       3           1          0
# 1     1      1986        2.0         1.0       5           0          0
# 2     0       909        1.0         1.0       3           1          0
# 3     6      1855        3.0         2.0       5           0          2
# 4     4      1226        1.0         1.0       3           1          2
#
#    REG_FEE  COMMIS  SALES_PRICE  AGE
# 0   380000  144400      7600000   44
# 1   760122  304049     21717770   11
# 2   421094   92114     13159200   20
# 3   356321   77042      9630290   22
# 4   237000   74063      7406250   30

# %%
df2.isna().sum()
# Out:
# AREA           0
# INT_SQFT       0
# N_BEDROOM      0
# N_BATHROOM     0
# N_ROOM         0
# PARK_FACIL     0
# BUILDTYPE      0
# REG_FEE        0
# COMMIS         0
# SALES_PRICE    0
# AGE            0
# dtype: int64

# %%
df2.fillna(1.0,inplace=True)

# %%
X=df2.drop('SALES_PRICE',axis='columns')
Y=df2.SALES_PRICE

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.2,random_state=0)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score,KFold

# %%
kf=KFold(n_splits=10,shuffle=True)

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_test,y_test)
# Out:
# 0.8541708194751673

# %%
cs=cross_val_score(lr,x_train,y_train,cv=kf)

# %%
cs.mean()
# Out:
# 0.8611191513454008

# %%
from sklearn.model_selection import GridSearchCV,ShuffleSplit

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
from xgboost import XGBRegressor

# %%
from sklearn.linear_model import Lasso

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
def best_model(a,b):
    algos={
        'linear regression':{
            'model':LinearRegression(),
            'param':{
                'normalize':[True,False]
            }
        },
        'lasso':{
            'model':Lasso(),
            'param':{
                'alpha':[1,2],
                'selection':['random','cyclic']
            }
        },
        'DecisionTreeRegressor':{
            'model':DecisionTreeRegressor(),
            'param':{
                'criterion':['mse','friedman_mse'],
                'splitter':['best','random']
            }
        },
        'XGBRegressor':{
            'model':XGBRegressor(),
            'param':{}
        }
    }
    scores=[]
    ss=ShuffleSplit(n_splits=5,test_size=0.2,random_state=0)
    for algos_name,para in algos.items():
        gs=GridSearchCV(para['model'],para['param'],cv=ss,return_train_score=False)
        gs.fit(a,b)
        scores.append({
            'Model':algos_name,
            'Best Score':gs.best_score_,
            'Best Params':gs.best_params_
        })
    return pd.DataFrame(scores,columns=['Model','Best Score','Best Params'])

# %%
best_model(X,Y)
# Out:
#                    Model  Best Score  \
# 0      linear regression    0.860325
# 1                  lasso    0.860325
# 2  DecisionTreeRegressor    0.929709
# 3           XGBRegressor    0.958623
#
#                                   Best Params
# 0                        {'normalize': False}
# 1         {'alpha': 1, 'selection': 'random'}
# 2  {'criterion': 'mse', 'splitter': 'random'}
# 3                                          {}

# %%
X.columns
# Out:
# Index(['AREA', 'INT_SQFT', 'N_BEDROOM', 'N_BATHROOM', 'N_ROOM', 'PARK_FACIL',
#        'BUILDTYPE', 'REG_FEE', 'COMMIS', 'AGE'],
#       dtype='object')

# %%
ss=ShuffleSplit(n_splits=5,test_size=0.2,random_state=0)
lrg=GridSearchCV(LinearRegression(),{'normalize':[False]},cv=ss,return_train_score=False)

# %%
lrg.fit(X,Y)
# Out:
# GridSearchCV(cv=ShuffleSplit(n_splits=5, random_state=0, test_size=0.2, train_size=None),
#              estimator=LinearRegression(), param_grid={'normalize': [False]})

# %%
lrg.predict([[0,909,1.0,1.0,3,1,0,421094,92114,20]])
# Out:
# array([12749446.11314032])

# %%
lrg.best_score_
# Out:
# 0.860325292990572

# %%
dtr=GridSearchCV(DecisionTreeRegressor(),{'criterion':['friedman_mse'],'splitter':['random']},cv=ss,return_train_score=False)

# %%
dtr.fit(X,Y)
# Out:
# GridSearchCV(cv=ShuffleSplit(n_splits=5, random_state=0, test_size=0.2, train_size=None),
#              estimator=DecisionTreeRegressor(),
#              param_grid={'criterion': ['friedman_mse'], 'splitter': ['random']})

# %%
dtr.best_score_
# Out:
# 0.9275711822699269

# %%
dtr.predict([[0,909,1.0,1.0,3,0,0,421094,92114,20]])
# Out:
# array([12099995.])

# %%
def prediction():
    print('------------AREA-----------\n1. Adyar\n2. Anna Nagar\n3. Chrompet\n4. KK Nagar\n5. Karapakkam\n6. T Nagar\n7. Velachery')
    
    a={'Adyar':0,'Anna Nagar':1,'Chrompet':2,'KK Nagar':3,'Karapakkam':4,'T Nagar':5,'Velachery':6}
    areas=input('Enter the Area : ')
    
    if areas not in a:
        print('Please enter valid Area')
    else:    
        
        area=a[areas]
        sqft=int(input('Enter Total SQ.FEET : '))
        n_bed=int(input('Number of Bedrooms : '))
        n_bath=int(input('Number of Bathrooms : '))
        n_room=int(input('Number of Rooms : '))
        
        p={'yes':1,'no':0}
        park=(input('You need a Parking ? (yes/no) :'))
        
        if park not in p:
            print('Please enter valid Parking option')
        else:    
            
            parking=p[park]
            bt={'commercial':0,'house':1,'others':2}
            typ=input('Type needed (commercial/house/others) : ')
            
            if areas not in a:
                    print('Please enter valid build type')
            else:        
                btype=bt[typ]
                reg_fee=int(input('Enter the Registeration Fee : '))
                commis=int(input('Enter the Commission : '))
                age=int(input('Enter the age of the building : '))
                
                result=dtr.predict([[area,sqft,n_bed,n_bath,n_room,parking,btype,reg_fee,commis,age]])[0]
                
                print("Your Estimation for your house :",(result)/100000,'lakhs')

# %%
prediction()
# Out:
# ------------AREA-----------
# 1. Adyar
# 2. Anna Nagar
# 3. Chrompet
# 4. KK Nagar
# 5. Karapakkam
# 6. T Nagar
# 7. Velachery
# Enter the Area : Adyar
# Enter Total SQ.FEET : 909
# Number of Bedrooms : 1
# Number of Bathrooms : 1
# Number of Rooms : 3
# You need a Parking ? (yes/no) :no
# Type needed (commercial/house/others) : commercial
# Enter the Registeration Fee : 421094
# Enter the Commission : 92114
# Enter the age of the building : 20
# Your Estimation for your house : 120.99995 lakhs

# %%
import pickle
with open ('house pricing pickle.pickle','wb') as f:
    pickle.dump(dtr,f)

# %%
import json
columns={
    'data_columns':[i.lower() for i in X.columns]
}
with open('columns.json','w') as f:
    f.write(json.dumps(columns))
